# %% [markdown]
# ### Daniel Gallegos NL = 20 Fecha 25/03/2026
# ---
# # Calcular area y perimetro de un circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/DanielGallegos128/EPPL-Area-de-un-triangulo/refs/heads/main/Areatriangulo.png)
#
# ---
# ## Formula para calcular Area
# $A = B * h/2$
#
# ---
# ## Datos de entrada
# * $B$ ?
# * $h$ ?
#
# ---
# ## Diagrama de flujo en LucidChart
# ![Logo de Markdown](https://raw.githubusercontent.com/DanielGallegos128/EPPL-Area-de-un-triangulo/refs/heads/main/DF%20AreaTriangulo.png)

# %%
# Calcular area de un triangulo
# Variables B, h, A
# Formulas (B*h)/2
B = float(input("Ingrese la base del triangulo: "))
h = float(input("Ingrese la altura del triangulo: "))
A = (B*h)/2
print("El area del triangulo es: ", A)
print("Programa realizado por Daniel Gallegos NL = 20")
# Out:
# Ingrese la base del triangulo: 4
# Ingrese la altura del triangulo: 7
# El area del triangulo es:  14.0
# Programa realizado por Daniel Gallegos NL = 20

# %% [markdown]
# # Relacion entre codigo y diagrama de flujo en Tldraw
#
# ---
# ![](https://raw.githubusercontent.com/DanielGallegos128/EPPL-Area-de-un-triangulo/refs/heads/main/Relacion%20DF%20y%20Codigo%20(2).png)
